# %%
import pandas as pd

bios = pd.read_csv("warmup_data/bios.csv")

# %% [markdown]
# <h1 style="color: red; font-size: 25px;"> Accessing Value </h1>
#
# <p style="color: orange;"> -> df.loc[a,b] <p>
# a = index / condition <br>
# b = columns that print <br>
# <h1 style="color: red; font-size: 25px;"> sort hand </h1>
#
# <p style="color: orange;">-> \df[a][b] <p>
# a = index / condition <br>
# b = columns that print <br>
# can apply multible condition <br>

# %%
print(bios.loc[bios["NOC"] == "Germany", ["name", "born_date", "died_date"]])
print(bios[bios["NOC"] == "Germany"][["name", "born_date", "died_date"]])
# Out:
#                      name   born_date   died_date
# 125            Anke Huber  1974-02-04         NaN
# 127           Dora Köring  1880-07-11  1945-02-13
# 130       Barbara Rittner  1973-04-25         NaN
# 131     Elke Schall-Wosik  1973-07-19         NaN
# 132        Katrin Schmidt  1967-09-28         NaN
# ...                   ...         ...         ...
# 144744       Pius Paschke  1990-05-20         NaN
# 144745  Constantin Schmid  1999-11-27         NaN
# 144746      Felix Rijhnen  1990-07-09         NaN
# 145453   Julian Rauchfuss  1994-09-02         NaN
# 145472   Tobias Schneider  1992-07-02         NaN
#
# [4714 rows x 3 columns]
#                      name   born_date   died_date
# 125            Anke Huber  1974-02-04         NaN
# 127           Dora Köring  1880-07-11  1945-02-13
# 130       Barbara Rittner  1973-04-25         NaN
# 131     Elke Schall-Wosik  1973-07-19         NaN
# 132        Katrin Schmidt  1967-09-28         NaN
# ...

# %%
bios.head(20)
# Out:
#     athlete_id                     name   born_date          born_city  \
# 0            1    Jean-François Blanchy  1886-12-12           Bordeaux
# 1            2           Arnaud Boetsch  1969-04-01             Meulan
# 2            3             Jean Borotra  1898-08-13           Biarritz
# 3            4          Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5             Albert Canet  1878-04-17         Wandsworth
# 5            6        Nicolas Chatelain  1970-01-13             Amiens
# 6            7            Patrick Chila  1969-11-27        Ris-Orangis
# 7            8             Henri Cochet  1901-12-14       Villeurbanne
# 8            9            Marcel Cousin  1896-08-04              Nîmes
# 9           10       Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours  1874-08-12            Orgeval
# 11          12              Max Decugis  1882-09-24         Paris XVIe
# ...
